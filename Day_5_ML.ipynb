# %% [markdown]
# <a href="https://colab.research.google.com/github/Mithil-Katkoria/Day-5_ML/blob/main/Day_5_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import *
from sklearn.linear_model import *
from sklearn.model_selection import *

# %%
data = pd.read_csv("/content/Car.csv")

# %%
data
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313     8221   Buick   Century  ...     4      1      1        1
# 1    17542.03608     9135   Buick   Century  ...     4      1      1        0
# 2    16218.84786    13196   Buick   Century  ...     4      1      1        0
# 3    16336.91314    16342   Buick   Century  ...     4      1      0        0
# 4    16339.17032    19832   Buick   Century  ...     4      1      0        1
# ..           ...      ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
data.shape
# Out:
# (804, 12)

# %%
data.head()
# Out:
#          Price  Mileage   Make    Model  ... Doors Cruise  Sound  Leather
# 0  17314.10313     8221  Buick  Century  ...     4      1      1        1
# 1  17542.03608     9135  Buick  Century  ...     4      1      1        0
# 2  16218.84786    13196  Buick  Century  ...     4      1      1        0
# 3  16336.91314    16342  Buick  Century  ...     4      1      0        0
# 4  16339.17032    19832  Buick  Century  ...     4      1      0        1
#
# [5 rows x 12 columns]

# %%
data.tail()
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [5 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     804 non-null    float64
#  1   Mileage   804 non-null    int64
#  2   Make      804 non-null    object
#  3   Model     804 non-null    object
#  4   Trim      804 non-null    object
#  5   Type      804 non-null    object
#  6   Cylinder  804 non-null    int64
#  7   Liter     804 non-null    float64
#  8   Doors     804 non-null    int64
#  9   Cruise    804 non-null    int64
#  10  Sound     804 non-null    int64
#  11  Leather   804 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 75.5+ KB

# %%
data
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313     8221   Buick   Century  ...     4      1      1        1
# 1    17542.03608     9135   Buick   Century  ...     4      1      1        0
# 2    16218.84786    13196   Buick   Century  ...     4      1      1        0
# 3    16336.91314    16342   Buick   Century  ...     4      1      0        0
# 4    16339.17032    19832   Buick   Century  ...     4      1      0        1
# ..           ...      ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
data.count()
# Out:
# Price       804
# Mileage     804
# Make        804
# Model       804
# Trim        804
# Type        804
# Cylinder    804
# Liter       804
# Doors       804
# Cruise      804
# Sound       804
# Leather     804
# dtype: int64

# %%
data
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313     8221   Buick   Century  ...     4      1      1        1
# 1    17542.03608     9135   Buick   Century  ...     4      1      1        0
# 2    16218.84786    13196   Buick   Century  ...     4      1      1        0
# 3    16336.91314    16342   Buick   Century  ...     4      1      0        0
# 4    16339.17032    19832   Buick   Century  ...     4      1      0        1
# ..           ...      ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['Price', 'Mileage', 'Make', 'Model', 'Trim', 'Type', 'Cylinder',
#        'Liter', 'Doors', 'Cruise', 'Sound', 'Leather'],
#       dtype='object')

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x = "Mileage", y = "Price",data = data)

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x = "Mileage", y = "Price",data = data,hue = "Cylinder")

# %%
data['Make'].value_counts()
# Out:
# Chevrolet    320
# Pontiac      150
# SAAB         114
# Cadillac      80
# Buick         80
# Saturn        60
# Name: Make, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.countplot(data["Model"])
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (12,8))
sns.countplot(data["Model"])
plt.xticks(rotation = 270)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (12,8))
sns.countplot(data["Model"])
plt.xticks(rotation = -45)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (12,8))
sns.countplot(data["Model"])
plt.xticks(rotation = 45)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cat_col = ['Make', 'Model', 'Trim', 'Type']
df_2 = pd.get_dummies(data[cat_col],drop_first = True)

# %%
scale = MinMaxScaler()
data['Mileage1'] = scale.fit_transform(data[['Mileage']])

# %%
data.head()
# Out:
#          Price   Mileage  Cylinder  Liter  ...  Cruise  Sound  Leather  Mileage1
# 0  17314.10313  0.158716         6    3.1  ...       1      1        1  0.158716
# 1  17542.03608  0.176952         6    3.1  ...       1      1        0  0.176952
# 2  16218.84786  0.257976         6    3.1  ...       1      1        0  0.257976
# 3  16336.91314  0.320744         6    3.1  ...       1      0        0  0.320744
# 4  16339.17032  0.390375         6    3.1  ...       1      0        1  0.390375
#
# [5 rows x 9 columns]

# %%
data
# Out:
#            Price   Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313  0.158716   Buick   Century  ...     4      1      1        1
# 1    17542.03608  0.176952   Buick   Century  ...     4      1      1        0
# 2    16218.84786  0.257976   Buick   Century  ...     4      1      1        0
# 3    16336.91314  0.320744   Buick   Century  ...     4      1      0        0
# 4    16339.17032  0.390375   Buick   Century  ...     4      1      0        1
# ..           ...       ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027  0.318489  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760  0.375671  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290  0.403384  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323  0.513018  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680  0.706211  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
data.drop(cat_col,axis = 1,inplace = True)

# %%
data
# Out:
#            Price   Mileage  Cylinder  Liter  Doors  Cruise  Sound  Leather
# 0    17314.10313  0.158716         6    3.1      4       1      1        1
# 1    17542.03608  0.176952         6    3.1      4       1      1        0
# 2    16218.84786  0.257976         6    3.1      4       1      1        0
# 3    16336.91314  0.320744         6    3.1      4       1      0        0
# 4    16339.17032  0.390375         6    3.1      4       1      0        1
# ..           ...       ...       ...    ...    ...     ...    ...      ...
# 799  16507.07027  0.318489         6    3.0      4       1      0        0
# 800  16175.95760  0.375671         6    3.0      4       1      1        0
# 801  15731.13290  0.403384         6    3.0      4       1      1        0
# 802  15118.89323  0.513018         6    3.0      4       1      1        0
# 803  13585.63680  0.706211         6    3.0      4       1      0        0
#
# [804 rows x 8 columns]

# %%
data.drop('Mileage1',axis = 1,inplace = True)

# %%
data
# Out:
#            Price   Mileage  Cylinder  Liter  Doors  Cruise  Sound  Leather
# 0    17314.10313  0.158716         6    3.1      4       1      1        1
# 1    17542.03608  0.176952         6    3.1      4       1      1        0
# 2    16218.84786  0.257976         6    3.1      4       1      1        0
# 3    16336.91314  0.320744         6    3.1      4       1      0        0
# 4    16339.17032  0.390375         6    3.1      4       1      0        1
# ..           ...       ...       ...    ...    ...     ...    ...      ...
# 799  16507.07027  0.318489         6    3.0      4       1      0        0
# 800  16175.95760  0.375671         6    3.0      4       1      1        0
# 801  15731.13290  0.403384         6    3.0      4       1      1        0
# 802  15118.89323  0.513018         6    3.0      4       1      1        0
# 803  13585.63680  0.706211         6    3.0      4       1      0        0
#
# [804 rows x 8 columns]

# %%
data_new = pd.concat([data,df_2],axis = 1)

# %%
data
# Out:
#            Price   Mileage  Cylinder  Liter  Doors  Cruise  Sound  Leather
# 0    17314.10313  0.158716         6    3.1      4       1      1        1
# 1    17542.03608  0.176952         6    3.1      4       1      1        0
# 2    16218.84786  0.257976         6    3.1      4       1      1        0
# 3    16336.91314  0.320744         6    3.1      4       1      0        0
# 4    16339.17032  0.390375         6    3.1      4       1      0        1
# ..           ...       ...       ...    ...    ...     ...    ...      ...
# 799  16507.07027  0.318489         6    3.0      4       1      0        0
# 800  16175.95760  0.375671         6    3.0      4       1      1        0
# 801  15731.13290  0.403384         6    3.0      4       1      1        0
# 802  15118.89323  0.513018         6    3.0      4       1      1        0
# 803  13585.63680  0.706211         6    3.0      4       1      0        0
#
# [804 rows x 8 columns]

# %%
data_new
# Out:
#            Price   Mileage  Cylinder  ...  Type_Hatchback  Type_Sedan  Type_Wagon
# 0    17314.10313  0.158716         6  ...               0           1           0
# 1    17542.03608  0.176952         6  ...               0           1           0
# 2    16218.84786  0.257976         6  ...               0           1           0
# 3    16336.91314  0.320744         6  ...               0           1           0
# 4    16339.17032  0.390375         6  ...               0           1           0
# ..           ...       ...       ...  ...             ...         ...         ...
# 799  16507.07027  0.318489         6  ...               0           1           0
# 800  16175.95760  0.375671         6  ...               0           1           0
# 801  15731.13290  0.403384         6  ...               0           1           0
# 802  15118.89323  0.513018         6  ...               0           1           0
# 803  13585.63680  0.706211         6  ...               0           1           0
#
# [804 rows x 94 columns]

# %%
x = data_new[['Mileage']]
y = data_new[['Price']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25)

# %%
x_train.shape
# Out:
# (603, 1)

# %%
y_train.shape
# Out:
# (603, 1)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.predict(x_test)
# Out:
# array([[24432.5732898 ],
#        [22364.67461052],
#        [20959.219664  ],
#        [20922.68112386],
#        [21081.07569537],
#        [23088.50309071],
#        [20731.76725162],
#        [21606.13451719],
#        [18505.10861543],
#        [20458.82435677],
#        [21077.78722675],
#        [21413.21102525],
#        [20060.55426923],
#        [20625.25740711],
#        [24881.99733353],
#        [18849.11897086],
#        [22455.29019007],
#        [23057.44533159],
#        [20913.54648882],
#        [21997.4622821 ],
#        [20409.31463488],
#        [23027.11834328],
#        [19915.49626487],
#        [22690.96377398],
#        [22847.89680388],
#        [21931.87560255],
#        [24062.80326357],
#        [20488.78595968],
#        [20881.0271881 ],
#        [24989.05525615],
#        [24112.86106357],
#        [22684.75222216],
#        [21416.68218656],
#        [20308.28557139],
#        [20217.66999184],
#        [20515.64178669],
#        [19722.57277293],
#        [23871.70669864],
#        [24056.04363365],
#        [22893.75267176],
#        [20011.22724004],
#        [20339.34333051],
#        [22637.06942727],
#        [21516.24970845],
#        [20009.58300573],
#        [20368.57416262],
#        [22034.73159305],
#        [21113.59499609],
#        [24658.56416057],
#        [20723.54608009],
#        [23426.66727972],
#        [21316.56658658],
#        [23456.81157533],
#        [20395.42998962],
#        [20792.60392095],
#        [19151.65808322],
#        [22142.70297916],
#        [20258.41046409],
#        [18641.76275555],
#        [20391.77613561],
#        [22569.10774261],
#        [21998.74113101],
#        [23924.68758184],
#        [20445.48778961],
#        [20400.91077064],
#        [22366.50153753],
#        [20302.43940496],
#        [21704.42319017],
#        [24769.0932445 ],
#        [21686.3366128 ],
#        [20967.44083553],
#        [23978.58192855],
#        [17961.59783083],
#        [23122.48393304],
#        [23137.6474272 ],
#        [20853.98866839],
#        [23464.48466876],
#        [22578.79045575],
#        [23521.66748408],
#        [21512.59585443],
#        [21494.32658436],
#        [20900.20992167],
#        [21146.47968222],
#        [22516.85763021],
#        [23229.72454836],
#        [19905.63085903],
#        [21474.96115809],
#        [21964.57759598],
#        [20285.6316765 ],
#        [22402.12661416],
#        [21675.55774346],
#        [19376.73549049],
#        [19720.74584592],
#        [22672.69450391],
#        [20652.84400492],
#        [21745.16366243],
#        [20589.44963777],
#        [19523.07234376],
#        [21412.84563985],
#        [21353.28781942],
#        [22481.04986087],
#        [21660.0288639 ],
#        [20934.0080713 ],
#        [24389.09242703],
#        [20433.97814947],
#        [21986.13533466],
#        [21770.55794783],
#        [20781.82505161],
#        [23804.84117018],
#        [23570.99451328],
#        [21276.00880702],
#        [24778.22787953],
#        [23496.27319869],
#        [18272.90619283],
#        [20483.12248596],
#        [20476.18016333],
#        [23698.87940377],
#        [19095.2060387 ],
#        [21666.24041573],
#        [21980.10647554],
#        [20667.27672827],
#        [21041.79676472],
#        [21209.32597126],
#        [20874.81563627],
#        [18834.8689402 ],
#        [20870.97908956],
#        [21165.47972309],
#        [20145.32368236],
#        [23990.63964679],
#        [20165.41987943],
#        [20681.16137352],
#        [23917.74525921],
#        [20705.27681002],
#        [19936.50592545],
#        [18735.11872562],
#        [19346.04311677],
#        [23376.42678702],
#        [21931.51021715],
#        [20327.83369036],
#        [20466.3147575 ],
#        [21709.72127849],
#        [21516.06701575],
#        [20369.48762612],
#        [22827.98329951],
#        [20463.02628888],
#        [21468.38422086],
#        [24396.21744236],
#        [20382.82419327],
#        [21438.97069605],
#        [20608.81506405],
#        [20856.3636735 ],
#        [23266.0803958 ],
#        [17501.76030316],
#        [21422.89373839],
#        [23083.57038779],
#        [20092.70818455],
#        [21960.92374196],
#        [20671.11327499],
#        [21083.63339318],
#        [21113.41230339],
#        [21275.46072892],
#        [20484.40133487],
#        [18672.63782197],
#        [22724.21384551],
#        [19395.73553136],
#        [24548.94854015],
#        [22884.80072943],
#        [22308.95333681],
#        [20457.54550786],
#        [22486.53064189],
#        [24757.03552625],
#        [21713.74051791],
#        [22694.06954989],
#        [24925.2955036 ],
#        [20882.306037  ],
#        [22933.21429511],
#        [20456.26665896],
#        [24979.37254301],
#        [24645.41028612],
#        [22967.74321555],
#        [21235.63372016],
#        [20310.66057649],
#        [18901.18639056],
#        [21913.60633248],
#        [20867.50792824],
#        [21597.36526756],
#        [24031.19742635],
#        [19855.39036634],
#        [21229.78755374],
#        [18312.55050888],
#        [21451.7591851 ],
#        [21780.24066097],
#        [21756.49060987],
#        [20557.11302975],
#        [22111.27983464],
#        [20850.33481438],
#        [22846.06987688],
#        [21574.52867997],
#        [22482.32870977],
#        [18890.95559932],
#        [21460.34574203]])
